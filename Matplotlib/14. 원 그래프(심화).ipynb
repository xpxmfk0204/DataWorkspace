# %% [markdown]
# # 14. 원 그래프(심화)

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'AppleGothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

values = [30, 25, 20, 13, 10, 2]
labels = ['Python', 'Java', 'Javascript', 'C#', 'C/C++', 'ETC']
#colors = ['b', 'g', 'r', 'c', 'm', 'y'] # 파트 별로 색 설정
colors = ['#ffadad', '#ffd6a5', '#fdffb6', '#caffbf', '#9bf6ff', '#a0c4ff']
explode = [0.05]*6

plt.pie(values, labels=labels, autopct='%.1f%%', startangle=90, counterclock=False, colors = colors, explode=explode)
plt.show()

# %%
wedgeprops={'width':0.6} # 원 그래프의 또다른 스타일, 중심에서 외각까지의 두께 설정
plt.pie(values, labels=labels, autopct='%.1f%%', startangle=90, counterclock=False, colors = colors, explode=explode, wedgeprops=wedgeprops)
plt.show()

# %%
wedgeprops={'width':0.6}
plt.pie(values, labels=labels, autopct='%.1f%%', startangle=90, counterclock=False, colors = colors, wedgeprops=wedgeprops)
plt.show() # explode를 없앤 모습

# %%
wedgeprops={'width':0.6, 'edgecolor':'w', 'linewidth':5}
plt.pie(values, labels=labels, autopct='%.1f%%', startangle=90, counterclock=False, colors = colors, wedgeprops=wedgeprops)
plt.show()
# explpde는 성분간에 위아래, 좌우 간격이 안맞는 경우가 있음, 따라서 explode를 없애 서로 붙인 후, 성분별 테두리를 흰색으로, 테두리 두께 조절해
# explode와 같은 효과를 나타내면 간격을 알맞게 설정 가능

# %%
def custom_autopct(pct):
    return ('%.1f%%' % pct) if pct >= 10 else ''
    #return '{:.1f}%'.format(pct) if pct >= 10 else '' # 윗줄과 같은 의미
    #return '{:.0f}%'.format(pct) if pct >= 10 else '' # 소숫점 없이

plt.pie(values, labels=labels, autopct=custom_autopct, startangle=90, counterclock=False, colors = colors, wedgeprops=wedgeprops)
plt.show()
# 비중이 10%가 넘는 경우에만 그래프에 수치 표시하는 함수 정의, autopct인자에 해당 함수 대입

# %%
def custom_autopct(pct):
    return ('%.1f%%' % pct) if pct >= 10 else ''

plt.pie(values, labels=labels, autopct=custom_autopct, startangle=90, counterclock=False, colors = colors, wedgeprops=wedgeprops, pctdistance=0.7)
plt.show()
# pctdistance: 수치 값의 중심으로부터의 거리 조절

# %% [markdown]
# ## DataFrame 활용

# %%
import pandas as pd
df = pd.read_excel('../Pandas/score.xlsx')
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197   90   85  100  95  85      Python
# 1   2번  정대만  북산고  184   40   35   50  55  25        Java
# 2   3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3   4번  서태웅  북산고  187   40   60   70  75  80         NaN
# 4   5번  강백호  북산고  188   15   20   10  35  10         NaN
# 5   6번  변덕규  능남고  202   80  100   95  85  80           C
# 6   7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7   8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
grp = df.groupby('학교')
grp

# %%
grp.size()
# Out:
# 학교
# 능남고    3
# 북산고    5
# dtype: int64

# %%
grp.size()['북산고']
# Out:
# 5

# %%
values = [grp.size()['북산고'], grp.size()['능남고']] # [5, 3]
labels = ['북산고', '능남고']

plt.pie(values, labels=labels, autopct='%.1f%%', startangle=90, counterclock=False, wedgeprops=wedgeprops)
plt.title('소속 학교')
plt.show()
